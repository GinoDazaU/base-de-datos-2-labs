# %% [markdown]
# <div style="border-radius: 5px; padding: 1rem; margin-bottom: 1rem">
# <img src="https://www.prototypesforhumanity.com/wp-content/uploads/2022/11/LOGO_UTEC_.png" alt="Banner" width="150" />
#  </div>
#
# # Laboratorio 3.2: Índice B+ Tree
# ### Organización de archivos
#
#
# > **Prof. Heider Sanchez**
# > **ACLs:** Ana María Accilio, Sebastián Loza

# %% [markdown]
# ## P1. B+ Tree: Ejercicio
#
# Las inserciones en el árbol B+ deben garantizar la propiedad de balanceo, por lo tanto, los nodos deben tener al menos `fb/2` entradas **(`fb` es el máximo número de entradas en un nodo)**. Las operaciones de inserción aplican división cuando un nodo se desborda, es decir, excede el factor de bloque.
#
# En este ejercicio se le pide generar el índice B+ agrupado y no-agrupado a partir de los datos mostrados en la **Tabla 1**. Considerar como factor de bloque `fb = 3` tanto en las paginas de datos como en las páginas de indexación.
#
#
# | #  | Cod  | Nombre             | Ciclo |
# |----|------|---------------------|--------|
# | 0  | 1JQ  | María López         | 1      |
# | 1  | A3H  | Gabriela Ramírez    | 6      |
# | 2  | B9Q  | Fernando Ortega     | 1      |
# | 3  | C4D  | Laura Fernández     | 1      |
# | 4  | D4Z  | Manuel Hernández    | 2      |
# | 5  | E3W  | Francisco Ruiz      | 2      |
# | 6  | F9M  | Sofía Rodríguez     | 2      |
# | 7  | G7L  | Ana García          | 9      |
# | 8  | H2K  | Luis Martínez       | 3      |
# | 9  | J8T  | Cristina López      | 8      |
# | 10 | L8J  | Paula Castro        | 2      |
# | 11 | M2F  | Elena Martínez      | 4      |
# | 12 | N5P  | Mariana Díaz        | 5      |
# | 13 | Q6N  | Carlos Gómez        | 5      |
# | 14 | R5B  | Pedro Sánchez       | 7      |
# | 15 | T1X  | Isabel Morales      | 3      |
# | 16 | V7K  | Javier Jiménez      | 3      |
# | 17 | W7L  | Ricardo Morales     | 3      |
# | 18 | Y4C  | Andrés Silva        | 2      |
# | 19 | Z8R  | Juan Pérez          | 7      |
#
#
# ---
#
#
# <u>Árbol Agrupado:</u> Usar el atributo “Cod” para crear el árbol agrupado.
#
# <u>Árbol No Agrupado:</u> Teniendo en cuenta que el archivo ya está ordenado por el código (físicamente no se debe alterar), por lo tanto se le pide construir dos índices B+ no-agrupado en los atributos Nombre y Ciclo.

# %% [markdown]
# > Solución aquí
# >
# >

# %% [markdown]
# ## P2. Unclustered B+ Tree: Diseño del Algoritmo
#
# Asuma que el índice B+ Tree **(Unclustered)** es trabajado completamente en memoria secundaria. Se le pide diseñar la estructura en `Python` e implementar el algoritmo de búsqueda.

# %%
SELECT * from Table WHERE key = 'yyy';

# %%
# Solución aquí

# %% [markdown]
# ## P3.  Clustered B+ Tree: Diseño del Algoritmo
# Diseñe el algoritmo de búsqueda por rango para el índice B+ Tree **(clustered)**, en memoria secundaria.

# %%
SELECT * from Table WHERE key BETWEEN 'aaa' AND 'ccc';

# %%
# Solución aquí

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=0cac3f27-ab57-45e1-94d7-eb1f84dca7ec' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
